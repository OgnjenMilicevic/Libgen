# %%
import argparse
import re
import os
from urllib import request
from urllib.parse import urlencode
#from tabulate import tabulate
from bs4 import BeautifulSoup
#from settings import *
import time
import pandas as pd
from functools import wraps

# %%
term = "10.1136/bmj.b1043"
page = 1
DOWNLOAD_PATH = "./fetched/"

def search_papers(term, page=1):
    params = urlencode({'q': term, 'page': page})
    url = "https://libgen.is/scimag/?{}".format(params)
    source = request.urlopen(url)
    soup = BeautifulSoup(source, 'lxml')

    papers_found = re.search(r'(\d+) files found', str(soup))
    print(papers_found.group())
    n_papers = int(papers_found.groups()[0])

    page_papers = soup.find_all('tr')
    return page_papers, n_papers


def save_book(download_link, file_name):
        if os.path.exists(DOWNLOAD_PATH) and os.path.isdir(DOWNLOAD_PATH):
            bad_chars = '\/:*?"<>|'
            for char in bad_chars:
                file_name = file_name.replace(char, " ")
            print('Downloading...')
            path = '{}/{}'.format(DOWNLOAD_PATH, file_name)
            request.urlretrieve(download_link, filename=path)
            print('Book downloaded to {}'.format(os.path.abspath(path)))
        elif os.path.isfile(DOWNLOAD_PATH):
            print('The download path is not a directory.')
        else:
            print('The download path does not exist.')

with open("test_doi.txt","r") as fin:
    dois = [line.strip() for line in fin]

raw_papers, n_papers = search_papers(term, page)
raw_paper = raw_papers[1]
#def process_paper(raw_paper):
book_attrs = raw_paper.find_all('td')
mirrors = book_attrs[4].find_all('a')
link = mirrors[1]["href"]
fname = book_attrs[1].text.strip().split('\n')[0] + ".pdf"
save_book(link, fname)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-101-ef949fe770c1> in <module>()
#      34     dois = [line.strip() for line in fin]
#      35
# ---> 36 raw_papers, n_papers = search_papers(term, page)
#      37 raw_paper = raw_papers[1]
#      38 #def process_paper(raw_paper):
#
# <ipython-input-101-ef949fe770c1> in search_papers(term, page)
#      10
#      11     papers_found = re.search(r'(\d+) files found', str(soup))
# ---> 12     print(papers_found.group())
#      13     n_papers = int(papers_found.groups()[0])
#      14
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
doi
# Out:
# '10.1016/j.amjmed.2016.03.008'

# %%
fname = "Nath Karl.xlsx"
#fname = "output.xlsx"
page = 1
DOWNLOAD_PATH = "./fetched/"


def retry(exceptions=(Exception,), tries=4, delay=3, backoff=2, logger=None, no_fail=True):
    """
    Retry calling the decorated function using an exponential backoff.

    Args:
        exceptions: The exception to check. may be a tuple of
            exceptions to check.
        tries: Number of times to try (not retry) before giving up.
        delay: Initial delay between retries in seconds.
        backoff: Backoff multiplier (e.g. value of 2 will double the delay
            each retry).
        logger: Logger to use. If None, print.
    """
    def deco_retry(f):

        @wraps(f)
        def f_retry(*args, **kwargs):
            mtries, mdelay = tries, delay
            while mtries > 1:
                try:
                    return f(*args, **kwargs)
                except exceptions as e:
                    msg = '{}, Retrying in {} seconds...'.format(e, mdelay)
                    if logger:
                        logger.warning(msg)
                    else:
                        print(msg)
                    time.sleep(mdelay)
                    mtries -= 1
                    mdelay *= backoff
            try:
                result = f(*args, **kwargs)
            except Exception as e:
                if no_fail:
                    result = None
                    print(e)
                else:
                    raise
            return result

        return f_retry  # true decorator

    return deco_retry


@retry()
def download(download_link, path):
    request.urlretrieve(download_link, filename=path)
    return os.path.getsize(path)


def search_papers(term, page=1):
    params = urlencode({'q': term, 'page': page})
    url = "https://libgen.is/scimag/?{}".format(params)
    tries = 0
    while tries < 3:
        
        try:
            source = request.urlopen(url)
            soup = BeautifulSoup(source, 'lxml')
            papers_found = re.search(r'(\d+) files found', str(soup))
            break

        except Exception as e:
            print(e)
            tries += 1
            time.sleep(2)
    else:
        papers_found = []
    

    if papers_found:
        n_papers = int(papers_found.groups()[0])

        page_papers = soup.find_all('tr')
        return page_papers, n_papers

    return None, 0


def save_book(download_link, file_name):
        if os.path.exists(DOWNLOAD_PATH) and os.path.isdir(DOWNLOAD_PATH):
            bad_chars = '\/:*?"<>|'
            for char in bad_chars:
                file_name = file_name.replace(char, " ")
            print('Downloading...')
            path = '{}/{}'.format(DOWNLOAD_PATH, file_name)
            size = download(download_link, path)
            if size and size != 0:
                print('Paper downloaded to {}'.format(os.path.abspath(path)))
                return size
            else:
                try:
                    os.remove(path)
                except:
                    pass
                print("{} download failed...".format(download_link))
        elif os.path.isfile(DOWNLOAD_PATH):
            print('The download path is not a directory.')
        else:
            print('The download path does not exist.')

#with open("test_doi.txt","r") as fin:
#    dois = [line.strip() for line in fin]
df = pd.read_excel(fname)
if 'Downloaded' not in df.columns:
    df["Downloaded"] = False

try:
    for index, row in df.iterrows():
        if row["Downloaded"] == True:
            print("Skipping downloaded {}".format(row["Title"]))
            continue
        doi = row["DOI"]
        if pd.isna(doi):
            #print("No DOI for {}".format(row["Title"]))
            continue        
        raw_papers, n_papers = search_papers(doi, page)
        if raw_papers:
            raw_paper = raw_papers[1]
            #def process_paper(raw_paper):
            book_attrs = raw_paper.find_all('td')
            mirrors = book_attrs[4].find_all('a')
            link = mirrors[1]["href"]
            fname = book_attrs[1].text.strip().split('\n')[0] + ".pdf"
            size = save_book(link, fname)
            if size:  # only if the book was downloaded (has size)
                df.at[index, "Downloaded"] = True
        time.sleep(1)
finally:
    df.to_excel("output.xlsx")
# Out:
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Protective effect of calcitriol on rhabdomyolysis-induced acute kidney injury in rats.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Establishment and characterization of a mouse model of rhabdomyolysis by coadministration of statin and fibrate.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Heme oxygenase-1 repeat polymorphism in septic acute kidney injury.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Hyperhomocysteinemia accelerates AKI to CKD progression by downregulating heme oxygenase-1 expression.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/The Contribution of Fluoride to the Pathogenesis of Eye Diseases  Molecular Mechanisms and Implications for Public Health.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Renal control of disease tolerance to malaria.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/A new pyridazinone exhibits potent cytotoxicity on human cancer cells via apoptosis and poly-ubiquitinated protein accumulation.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Iron Homeostasis in Healthy Kidney and its Role in Acute Kidney Injury.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Mechanisms and consequences of oxidant-induced renal preconditioning  an Nrf2-dependent, P21-independent, anti-senescence pathway.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Iron Homeostasis Pathways as Therapeutic Targets in Acute Kidney Injury.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Nitrolipids in kidney physiology and disease.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/  no title  .pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Transmembrane BAX Inhibitor Motif-6 (TMBIM6) protects against cisplatin-induced testicular toxicity.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Heme Oxygenase-1 Mitigates Ferroptosis in Renal Proximal Tubule Cells.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Sexual Dimorphic Pattern of Renal Transporters and Electrolyte Homeostasis.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Unique sex- and age-dependent effects in protective pathways in acute kidney injury.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Dynamic changes in Bach1 expression in the kidney of rhabdomyolysis-associated acute kidney injury.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Protective Role for Antioxidants in Acute Kidney Disease.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Heme as a Target for Therapeutic Interventions.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Heme Oxygenase 1 as a Therapeutic Target in Acute Kidney Injury.pdf
# Downloading...
# <urlopen error retrieval incomplete: got only 0 out of 1761929 bytes>, Retrying in 3 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 1761929 bytes>, Retrying in 6 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 1761929 bytes>, Retrying in 12 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 1761929 bytes>
# http://libgen.io/scimag/get.php?doi=10.1016/j.biocel.2017.01.003 download failed...
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Endothelial STAT3 Modulates Protective Mechanisms in a Mouse Ischemia-Reperfusion Model of Acute Kidney Injury.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Alleviating Promotion of Inflammation and Cancer Induced by Nonsteroidal Anti-Inflammatory Drugs.pdf
# Downloading...
# <urlopen error retrieval incomplete: got only 0 out of 1615907 bytes>, Retrying in 3 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 1615907 bytes>, Retrying in 6 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 1615907 bytes>, Retrying in 12 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 1615907 bytes>
# http://libgen.io/scimag/get.php?doi=10.1016/j.freeradbiomed.2016.10.012 download failed...
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Effects of hemin on heme oxygenase-1, gastric emptying, and symptoms in diabetic gastroparesis.pdf
# Downloading...
# <urlopen error retrieval incomplete: got only 0 out of 1290588 bytes>, Retrying in 3 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 1290588 bytes>, Retrying in 6 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 1290588 bytes>, Retrying in 12 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 1290588 bytes>
# http://libgen.io/scimag/get.php?doi=10.1007/s13546-016-1229-9 download failed...
# Downloading...
# <urlopen error retrieval incomplete: got only 0 out of 872929 bytes>, Retrying in 3 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 872929 bytes>, Retrying in 6 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 872929 bytes>, Retrying in 12 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 872929 bytes>
# http://libgen.io/scimag/get.php?doi=10.1080/0886022X.2016.1227925 download failed...
# Downloading...
# <urlopen error retrieval incomplete: got only 0 out of 2582132 bytes>, Retrying in 3 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 2582132 bytes>, Retrying in 6 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 2582132 bytes>, Retrying in 12 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 2582132 bytes>
# http://libgen.io/scimag/get.php?doi=10.1152/physrev.00003.2016 download failed...
# Downloading...
# <urlopen error retrieval incomplete: got only 0 out of 1817036 bytes>, Retrying in 3 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 1817036 bytes>, Retrying in 6 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 1817036 bytes>, Retrying in 12 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 1817036 bytes>
# http://libgen.io/scimag/get.php?doi=10.1038/aps.2016.71 download failed...
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Editorial  Molecular Mechanisms Protecting against Tissue Injury.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/The role of myoglobin degradation in nephrotoxicity after rhabdomyolysis.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Delayed Mitogen-Activated Protein Kinase Extracellular Signal–Regulated Kinase Inhibition by Trametinib Attenuates Systemic Inflammatory Responses and Multiple Organ Injury in Murine Sepsis.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Heme oxygenase-1 in kidney health and disease.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Iron, hormesis, and protection in acute kidney injury.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Combined iron sucrose and protoporphyrin treatment protects against ischemic and toxin-mediated acute renal failure.pdf
# Downloading...
# <urlopen error retrieval incomplete: got only 0 out of 936330 bytes>, Retrying in 3 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 936330 bytes>, Retrying in 6 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 936330 bytes>, Retrying in 12 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 936330 bytes>
# http://libgen.io/scimag/get.php?doi=10.1159/000446859 download failed...
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/The proximal tubule is the primary target of injury and progression of kidney disease  role of the glomerulotubular junction.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Renoprotective approaches and strategies in acute kidney injury.pdf
# Downloading...
# <urlopen error retrieval incomplete: got only 0 out of 807274 bytes>, Retrying in 3 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 807274 bytes>, Retrying in 6 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 807274 bytes>, Retrying in 12 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 807274 bytes>
# http://libgen.io/scimag/get.php?doi=10.1248/bpb.b15-01028 download failed...
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Macrophages and Iron Metabolism.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Proximal tubule-targeted heme oxygenase-1 in cisplatin-induced acute kidney injury.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Identification of Genes and Pathways Associated with Kidney Ischemia-Reperfusion Injury by Bioinformatics Analyses.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Red alert  labile heme is an alarmin.pdf
# Downloading...
# <urlopen error retrieval incomplete: got only 0 out of 457158 bytes>, Retrying in 3 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 457158 bytes>, Retrying in 6 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 457158 bytes>, Retrying in 12 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 457158 bytes>
# http://libgen.io/scimag/get.php?doi=10.1681/ASN.2016060699 download failed...
# Downloading...
# <urlopen error retrieval incomplete: got only 0 out of 686186 bytes>, Retrying in 3 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 686186 bytes>, Retrying in 6 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 686186 bytes>, Retrying in 12 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 686186 bytes>
# http://libgen.io/scimag/get.php?doi=10.1152/ajprenal.00388.2016 download failed...
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Emodin Attenuates Cigarette Smoke Induced Lung Injury in a Mouse Model via Suppression of Reactive Oxygen Species Production.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/
pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Kohlenmonoxid  toxisches Molekül mit antiinflammatorischen und zytoprotektiven Eigenschaften.pdf
# Downloading...
# <urlopen error retrieval incomplete: got only 0 out of 3474498 bytes>, Retrying in 3 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 3474498 bytes>, Retrying in 6 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 3474498 bytes>, Retrying in 12 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 3474498 bytes>
# http://libgen.io/scimag/get.php?doi=10.1620/tjem.208.179 download failed...
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Heme oxygenase-1  a new drug target in oxidative tissue injuries in critically ill conditions.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/PROTECTIVE EFFECTS OF l-CARNITINE ON MYOGLOBINURIC ACUTE RENAL FAILURE IN RATS.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Proteinuria as a determinant of renal expression of heme oxygenase-1  studies in models of glomerular and tubular proteinuria in the rat.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Hemodialysis reduces inhibitory effect of plasma ultrafiltrate on LDL oxidation and subsequent endothelial reactions.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Treatment with CO-RMs during cold storage improves renal function at reperfusion.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Anomalous Renal Effects of Tin Protoporphyrin in a Murine Model of Sickle Cell Disease.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Role of heme oxygenase-1 in endotoxemic acute renal failure.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Differential regulation of the rat heme oxygenase-1 expression by Ets oncoproteins in glomerular mesangial cells.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Increase in heme oxygenase-1 levels ameliorates renovascular hypertension.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/[Contributions to Nephrology] Cellular Stress Responses in Renal Diseases    Cytoprotective Effects of Heme Oxygenase in Acute Renal Failure.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Carbon Monoxide  Endogenous Production, Physiological Functions, and Pharmacological Applications.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Heme, heme oxygenase and ferritin in vascular endothelial cell injury.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Glomerular Proteinuria Induces Heme Oxygenase-1 Gene Expression within Renal Epithelial Cells.pdf
# Downloading...
# HTTP Error 502: Bad Gateway, Retrying in 3 seconds...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Effects of Amifostine on Glycerol-Pretreated Rabbit Kidneys.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Heat Shock Protein 32 in Human Peripheral Blood Mononuclear Cells  Effect of Aging and Inflammation.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/MCP-1 is up-regulated in unstressed and stressed HO-1 knockout mice  Pathophysiologic correlates1.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Heme oxygenase and the cardiovascular–renal system.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Molsidomine, a nitric oxide donor and l-arginine protects against rhabdomyolysis-induced myoglobinuric acute renal failure.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Heme oxygenase-1 inhibits cigarette smoke-induced increase in the tracheal mucosal permeability in guinea pigs in vivo.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Protective effects of exogenous bilirubin on ischemia-reperfusion injury in the isolated, perfused rat kidney.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/The possible role of heat shock factor-1 in the negative regulation of heme oxygenase-1.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/The hyperbilirubinemic Gunn rat is resistant to the pressor effects of angiotensin II.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Adenovirus-Mediated Transfer and Overexpression of Heme Oxygenase 1 cDNA in Lungs Attenuates Elastase-Induced Pulmonary Emphysema in Mice.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/N-acetylcysteine attenuates early induction of heme oxygenase-1 following traumatic brain injury.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Celecoxib Induces Heme-Oxygenase Expression in Glomerular Mesangial Cells.pdf
# Downloading...
# ...
# Downloading...
# <urlopen error retrieval incomplete: got only 0 out of 123960 bytes>, Retrying in 3 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 123960 bytes>, Retrying in 6 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 123960 bytes>, Retrying in 12 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 123960 bytes>
# http://libgen.io/scimag/get.php?doi=10.1042/0264-6021%3A3440153 download failed...
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Role of Heme Oxygenase in Pulmonary Response to Antigen Challenge in Sensitized Rats in vivo.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Induction of Heme Oxygenase-1 Suppresses Venular Leukocyte Adhesion Elicited by Oxidative Stress   Role of Bilirubin Generated by the Enzyme.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Redox regulation and oxidant activation of heme oxygenase-1.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Heme Oxygenase Inhibitors Transiently Increase Serum Ferritin Concentrations without Altering Other Acute-Phase Reactants in Man.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Heme oxygenase and cardiac function in ischemic reperfused rat hearts.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Expression of heme oxygenase-1 mediated by non-NMDA and metabotropic receptors in glial cells  possible involvement of reactive oxygen species production and protein kinase C activation.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/In vitro erythrophagocytosis by renal tubular cells and tubular toxicity by haemoglobin and iron.pdf
# Downloading...
# <urlopen error retrieval incomplete: got only 0 out of 133446 bytes>, Retrying in 3 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 133446 bytes>, Retrying in 6 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 133446 bytes>, Retrying in 12 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 133446 bytes>
# http://libgen.io/scimag/get.php?doi=10.1183/09031936.99.13104899 download failed...
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Extracellular Signal-Regulated Kinase Mediates Renal Regeneration in Rats with Myoglobinuric Acute Renal Injury.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Negative Regulation of Human Heme Oxygenase in Microvessel Endothelial Cells by Dexamethasone .pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Central Hemodynamic Changes in Experimental Muscle Crush Injury in Pigs.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Exhaled Carbon Monoxide Levels Elevated in Diabetes and Correlated With Glucose Concentration in Blood.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Increased proximal tubular cholesterol content  Implications for cell injury and  acquired cytoresistance .pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Differential regulation and expression of stress proteins and ferritin in human monocytes.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Protective Effects of Heme Oxygenase-1 against Oxidant-Induced Injury in the Cultured Human Tracheal Epithelium.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/ROLE OF REACTIVE OXYGEN SPECIES FOR HEPATOCELLULAR INJURY AND HEME OXYGENASE-1 GENE EXPRESSION AFTER HEMORRHAGE AND RESUSCITATION.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Increased carbon monoxide in exhaled air of patients with cystic fibrosis.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Nitric oxide mediates the lipopolysaccharide dependent upregulation of the heme oxygenase-1 gene expression in cultured rat Kupffer cells.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Calcitriol Directly Sensitizes Renal Tubular Cells to ATP-Depletion- and Iron-Mediated Attack.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Increased oxidative stress in mouse kidneys with unilateral ureteral obstruction.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/The heme oxygenase pathway and its interaction with nitric oxide in the control of cellular homeostasis.pdf
# Downloading...
# <urlopen error retrieval incomplete: got only 0 out of 329831 bytes>, Retrying in 3 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 329831 bytes>, Retrying in 6 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 329831 bytes>, Retrying in 12 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 329831 bytes>
# http://libgen.io/scimag/get.php?doi=10.1042/bj3340141 download failed...
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Kainic acid induction of heme oxygenase in vivo and in vitro.pdf
# Downloading...
#               -Associated Nephrotoxicity  Correlation of Renal Function and Morphology.pdf Acute Renal Failure Attenuates Subsequent HgCl
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/
df
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Rhabdomyolysis and myohemoglobinuric acute renal failure.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/The Biological Significance and Physiological Role of Heme Oxygenase.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Induction of Ferritin Synthesis by Oxidative Stress  TRANSCRIPTIONAL AND POST-TRANSCRIPTIONAL REGULATION BY EXPANSION OF THE  FREE  IRON POOL.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/  no title  .pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Antioxidants attenuate glycerol-endotoxin induced acute renal failure in rats.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Heme protein-induced tubular cytoresistance  Expression at the plasma membrane level.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Iron, heme oxygenase, and glutathione  Effects on myohemoglobinuric proximal tubular injury.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Obstruction of proximal tubules initiates cytoresistance against hypoxic damage.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/TWO GENES CONTRIBUTE TO DIFFERENT EXTENTS TO THE HEME OXYGENASE ENZYME ACTIVITY MEASURED IN CULTURED HUMAN SKIN FIBROBLASTS AND KERATINOCYTES  IMPLICATIONS FOR PROTECTION AGAINST OXIDANT STRESS.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Heme protein-mediated renal injury  A protective role for 21-aminosteroids in vitro and in vivo.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Induction of heme oxygenase in toxic renal injury  A protective role in cisplatin nephrotoxicity in the rat.pdf
# Downloading...
# <urlopen error retrieval incomplete: got only 0 out of 1460230 bytes>, Retrying in 3 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 1460230 bytes>, Retrying in 6 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 1460230 bytes>, Retrying in 12 seconds...
# <urlopen error retrieval incomplete: got only 0 out of 1460230 bytes>
# http://libgen.io/scimag/get.php?doi=10.1248/jhs1956.41.14 download failed...
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Heme oxygenase 1 mediates an adaptive response to oxidative stress in human skin fibroblasts..pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Increased expression of heme oxygenase-1 in human retinal pigment epithelial cells by transforming growth factor-β.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Most free-radical injury is iron-related  It is promoted by iron, hemin, holoferritin and vitamin c, and inhibited by desferoxamine and apoferritin.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Acute renal failure in the setting of bone marrow transplatation.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/[Advances in Pharmacology]  Volume 30    Pharmacologic Management of Shock-Induced Renal Dysfunction.pdf
# Downloading...
# Paper downloaded to /Users/ognjenmilicevic/PythonPlay/Self/Libgen/fetched/Endothelial Activation and the Kidney  Vasomediator Modulation and Antioxidant Strategies.pdf

# %%
sum(df["Downloaded"] == True)
# Out:
# 411

# %%
df.at[index,"DOI"]
# Out:
# '10.1016/bs.apha.2016.04.006'

# %%
index
# Out:
# 25

# %%
df.to_excel("output.xlsx")

# %%
def retry(arg1,arg2):
    def wrapper(f):
        print(f.__name__)
        def wrapped_function(*args,**kwargs):
            print(args)
            print(arg1, arg2)
            return args, arg1, arg2
        
        return wrapped_function
    return wrapper

@arg_wrapper(1,2)    
def sum1(m, n):
    print(m, n)
    
print(sum1(6, "cow"))
# Out:
# sum1
# (6, 'cow')
# 1 2
# ((6, 'cow'), 1, 2)

# %%
Exception
# Out:
# Exception

# %%
'Downloaded' in df.columns
# Out:
# True

# %%
for index, row in df.iterrows():
    doi = row["DOI"]
    print(pd.isna(doi))
    #print(type(doi))
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# True
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# True
# True
# False
# True
# True
# True
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# False
# False
# False
# True
# False
# False
# True
# False
# False
# False
# False
# False
# True
# False
# False
# False
# True
# True
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# True
# True
# False
# False
